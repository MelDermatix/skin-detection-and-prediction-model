# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution2D
Conv2D = Convolution2D

# %%
from tensorflow.keras.layers import Flatten, Dense, Dropout

# %%
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, Activation

# %%
model = Sequential()

# %%
model.add(Conv2D(32, (3, 3), input_shape=(64,64,3), activation='relu'))

# %%
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
model.add(Flatten())

# %%
model.add(Dense(units=128, activation='relu'))

# %%
model.add(Dense(units=7, activation='softmax'))

# %%
model.compile(optimizer = 'adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import matplotlib.pyplot as plt

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip=True)

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory('training set',
                                                target_size = (64,64),
                                                batch_size = 32,
                                                class_mode = 'binary')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-724cd49f39bf> in <module>
# ----> 1 training_set = train_datagen.flow_from_directory('training set',
#       2                                                 target_size = (64,64),
#       3                                                 batch_size = 32,
#       4                                                 class_mode = 'binary')
#
# NameError: name 'train_datagen' is not defined

# %%
test_set = test_datagen.flow_from_directory('test set',
                                                target_size = (64,64),
                                                batch_size = 32,
                                                class_mode = 'binary')
# Out:
# Found 93 images belonging to 7 classes.

# %%
from IPython.display import display

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
model.fit_generator(
    training_set,
    epochs=20)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 3s 695ms/step - loss: 0.1285 - acc: 0.9685
# Epoch 2/20
# 4/4 [==============================] - 2s 500ms/step - loss: 0.1169 - acc: 0.9764
# Epoch 3/20
# 4/4 [==============================] - 2s 497ms/step - loss: 0.1092 - acc: 0.9921
# Epoch 4/20
# 4/4 [==============================] - 2s 480ms/step - loss: 0.1357 - acc: 0.9685
# Epoch 5/20
# 4/4 [==============================] - 2s 513ms/step - loss: 0.1505 - acc: 0.9764
# Epoch 6/20
# 4/4 [==============================] - 2s 442ms/step - loss: 0.1148 - acc: 0.9921
# Epoch 7/20
# 4/4 [==============================] - 2s 466ms/step - loss: 0.1233 - acc: 0.9764
# Epoch 8/20
# 4/4 [==============================] - 2s 491ms/step - loss: 0.1090 - acc: 0.9843
# Epoch 9/20
# 4/4 [==============================] - 2s 570ms/step - loss: 0.0853 - acc: 1.0000
# Epoch 10/20
# 4/4 [==============================] - 3s 653ms/step - loss: 0.0985 - acc: 0.9843
# Epoch 11/20
# 4/4 [==============================] - 2s 481ms/step - loss: 0.1228 - acc: 0.9843
# Epoch 12/20
# 4/4 [==============================] - 2s 505ms/step - loss: 0.0966 - acc: 0.9921
# Epoch 13/20
# 4/4 [==============================] - 2s 500ms/step - loss: 0.0810 - acc: 0.9921
# Epoch 14/20
# 4/4 [==============================] - 2s 530ms/step - loss: 0.0814 - acc: 0.9921
# Epoch 15/20
# 4/4 [==============================] - 2s 490ms/step - loss: 0.0866 - acc: 0.9843
# Epoch 16/20
# 4/4 [==============================] - 2s 488ms/step - loss: 0.0925 - acc: 0.9921
# Epoch 17/20
# 4/4 [==============================] - 2s 559ms/step - loss: 0.0835 - acc: 0.9921
# Epoch 18/20
# 4/4 [==============================] - 2s 454ms/step - loss: 0.0720 - acc: 1.0000
# Epoch 19/20
# 4/4 [==============================] - 2s 520ms/step - loss: 0.0900 - acc: 0.9843
# Epoch 20/20
# 4/4 [==============================] - 2s 522ms/step - loss: 0.0655 - acc: 1.0000

# %%
import numpy as np

# %%
from IPython.display import Image

# %%
from tensorflow.keras.preprocessing import image

# %%
test_image = image.load_img('C:\\Users\\pc\\Desktop\\dataset\\test set\\eczema\\06.jpg', target_size = (64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)

# %%
result = model.predict(test_image)

# %%
training_set.class_indices
# Out:
# {'auto immune disease': 0,
#  'bacterial infection': 1,
#  'eczema': 2,
#  'fungal yeast infection': 3,
#  'miscellaneous skin diseases': 4,
#  'parasitic infection': 5,
#  'viral infection': 6}

# %%
if result[0][0] ==1:
    prediction = 'auto immune disease'
elif result[0][1] == 1:
    prediction = 'bacterial infection'
elif result[0][2] == 1:
    prediction = 'eczema'
elif result[0][3] == 1:
    prediction = 'fungal yeast infection'
elif result[0][4] == 1:
    prediction = 'miscellaneous skin diseases'
elif result[0][5] == 1:
    prediction = 'parasitic infection' 
else:
    prediction = 'viral infection'
print(prediction)
Image('C:\\Users\\pc\\Desktop\\dataset\\test set\\eczema\\06.jpg')
# Out:
# eczema
